# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # Big Query

# %% [markdown]
# ## Load Time

# %% [markdown]
# ### TPCH_05_loading_times

# %%
# Load the provided CSV file
file_path = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/BigQueryLoadTime/TPCH_05_loading_times.csv'
data = pd.read_csv(file_path)

# Set a style for the plot
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x='Loading Time', y='Dataset', data=data, palette='viridis')

# Adding the title and labels
plt.title('Loading Times of Different Datasets', fontsize=16)
plt.xlabel('Loading Time (seconds)', fontsize=14)
plt.ylabel('Dataset', fontsize=14)

# Annotating the bars with the values
for p in barplot.patches:
    width = p.get_width()
    plt.text(width + 0.3, p.get_y() + p.get_height() / 2, f'{width:.2f}', va='center')

# Display the plot
plt.show()

# %% [markdown]
# ### TPCH_1G_loading_times

# %%
# Load the provided CSV file
file_path = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/BigQueryLoadTime/TPCH_1G_loading_times.csv'
data = pd.read_csv(file_path)

# Set a style for the plot
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x='Loading Time', y='Dataset', data=data, palette='viridis')

# Adding the title and labels
plt.title('Loading Times of Different Datasets', fontsize=16)
plt.xlabel('Loading Time (seconds)', fontsize=14)
plt.ylabel('Dataset', fontsize=14)

# Annotating the bars with the values
for p in barplot.patches:
    width = p.get_width()
    plt.text(width + 0.3, p.get_y() + p.get_height() / 2, f'{width:.2f}', va='center')

# Display the plot
plt.show()

# %% [markdown]
# ### TPCH_2G_loading_times

# %%
# Load the provided CSV file
file_path = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/BigQueryLoadTime/TPCH_2G_loading_times.csv'
data = pd.read_csv(file_path)

# Set a style for the plot
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x='Loading Time', y='Dataset', data=data, palette='viridis')

# Adding the title and labels
plt.title('Loading Times of Different Datasets', fontsize=16)
plt.xlabel('Loading Time (seconds)', fontsize=14)
plt.ylabel('Dataset', fontsize=14)

# Annotating the bars with the values
for p in barplot.patches:
    width = p.get_width()
    plt.text(width + 0.3, p.get_y() + p.get_height() / 2, f'{width:.2f}', va='center')

# Display the plot
plt.show()

# %% [markdown]
# ### TPCH_3G_loading_times

# %%
# Load the provided CSV file
file_path = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/BigQueryLoadTime/TPCH_3G_loading_times.csv'
data = pd.read_csv(file_path)

# Set a style for the plot
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x='Loading Time', y='Dataset', data=data, palette='viridis')

# Adding the title and labels
plt.title('Loading Times of Different Datasets', fontsize=16)
plt.xlabel('Loading Time (seconds)', fontsize=14)
plt.ylabel('Dataset', fontsize=14)

# Annotating the bars with the values
for p in barplot.patches:
    width = p.get_width()
    plt.text(width + 0.3, p.get_y() + p.get_height() / 2, f'{width:.2f}', va='center')

# Display the plot
plt.show()

# %% [markdown]
# ### Time Summary

# %%
# List of file paths for the uploaded CSV files
file_paths = [
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/BigQueryLoadTime/TPCH_05_loading_times.csv',
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/BigQueryLoadTime/TPCH_1G_loading_times.csv',
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/BigQueryLoadTime/TPCH_2G_loading_times.csv',
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/BigQueryLoadTime/TPCH_3G_loading_times.csv'
]

# Read each CSV file and store them in a list
datasets = [pd.read_csv(file) for file in file_paths]

# Display the structure of the first dataset to understand how to combine them
datasets[0].head()

# Create a new DataFrame to hold all the combined data with an additional 'File Size' column
combined_data = pd.DataFrame()

# Loop over each dataset and append to the combined_data DataFrame
for i, dataset in enumerate(datasets):
    dataset['File Size'] = f"{i}G" if i > 0 else "0.5G"  # Assign file size based on the order
    combined_data = combined_data.append(dataset, ignore_index=True)

# Set the order of file sizes to maintain consistency in the plot
file_size_order = ["0.5G", "1G", "2G", "3G"]

pivot_data = combined_data.pivot(index='Dataset', columns='File Size', values='Loading Time')

# Define a simple color scheme
color_scheme = ['#A6CEE3', '#1F78B4', '#B2DF8A', '#33A02C']

# Plot
fig, ax = plt.subplots(figsize=(14, 10))

# We stack the bars using a cumulative sum to place them on top of each other
bottom = np.zeros(len(pivot_data))

# Loop to plot the bars
for i, col in enumerate(pivot_data.columns[::-1]):  # Reverse the order for proper stacking
    ax.bar(pivot_data.index, pivot_data[col], bottom=bottom, label=col, color=color_scheme[i])
    bottom += pivot_data[col].values

# Adding the title and labels with a more academic look
ax.set_title('Loading Times by Dataset and File Size', fontsize=20, weight='bold')
ax.set_xlabel('Dataset', fontsize=16, weight='bold')
ax.set_ylabel('Loading Time (seconds)', fontsize=16, weight='bold')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', rotation_mode='anchor', weight='bold')

# Adding a legend with a clear label
ax.legend(title='File Size', title_fontsize='13', loc='upper right', fontsize='12')

# Set the background to white with no gridlines for a clean look
ax.set_facecolor('white')
ax.grid(False)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-57-8eed115c370f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(dataset, ignore_index=True)
# <ipython-input-57-8eed115c370f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(dataset, ignore_index=True)
# <ipython-input-57-8eed115c370f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(dataset, ignore_index=True)
# <ipython-input-57-8eed115c370f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(dataset, ignore_index=True)

# %% [markdown]
# ## Execution Time

# %% [markdown]
# ### TPC Total

# %%
# It seems we only loaded one of the execution_times.csv files previously.
# Let's load each execution_times.csv file as a separate dataset.
# As they have the same name, we'll load them one by one to avoid confusion.

# Define the paths for the three execution_times files (assuming they are different)
execution_times_paths = [
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/PUBLIC/execution_times.csv',  # Assuming this path is for the first file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/TPCH_1G/execution_times.csv',  # Assuming this path is for the second file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/TPCH_2G/execution_times.csv',  # Assuming this path is for the third file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/TPCH_3G/execution_times.csv'   # This is the fourth file
]

# Read the content of the CSV files
# Since the files have the same name, we'll load them one by one
execution_times_data = []
for i, path in enumerate(execution_times_paths):
    temp_data = pd.read_csv(path)
    temp_data['Dataset'] =  f"{i}G" if i > 0 else "0.5G"
    execution_times_data.append(temp_data)

# Combine all datasets into one DataFrame
combined_execution_data_all = pd.concat(execution_times_data, ignore_index=True)

# Now let's create the comparison plot for all four datasets.
plt.figure(figsize=(16, 10))
sns.boxplot(x='SQL_File', y='Run_Time', hue='Dataset', data=combined_execution_data_all, palette="Set3")

# Adding the title and labels
plt.title('Comparison of SQL File Execution Times Across Four Datasets', fontsize=20)
plt.xlabel('SQL File', fontsize=16)
plt.ylabel('Execution Time (seconds)', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Re-create the boxplot without showing the outliers
plt.figure(figsize=(16, 10))
sns.boxplot(x='SQL_File', y='Run_Time', hue='Dataset', data=combined_execution_data_all,
            palette="Set3", showfliers=False)  # showfliers=False will hide the outliers

# Adding the title and labels
plt.title('Comparison of SQL File Execution Times Across Four Datasets (Without Outliers)', fontsize=20)
plt.xlabel('SQL File', fontsize=16)
plt.ylabel('Execution Time (seconds)', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Throughput_time_cu4

# %%
# Load the remaining three files as separate datasets
execution_time_file_1 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu4/PUBLIC/execution_times.csv'
execution_time_file_2 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu4/TPCH_1G/execution_times.csv'  # Second file
execution_time_file_3 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu4/TPCH_2G/execution_times.csv'  # Third file
execution_time_file_4 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu4/TPCH_3G/execution_times.csv'  # Fourth file

data1 = pd.read_csv(execution_time_file_1)
data1['Dataset'] = 'TPCH_05G'

# Load the second file and add an identifier
data2 = pd.read_csv(execution_time_file_2)
data2['Dataset'] = 'TPCH_1G'

# Load the third file and add an identifier
data3 = pd.read_csv(execution_time_file_3)
data3['Dataset'] = 'TPCH_2G'

# Load the fourth file and add an identifier
data4 = pd.read_csv(execution_time_file_4)
data4['Dataset'] = 'TPCH_3G'

# Combine all datasets into one DataFrame
combined_execution_data = pd.concat([data1, data2, data3, data4], ignore_index=True)

# Check for any negative or extremely large run times in the combined data
negative_times = combined_execution_data[combined_execution_data['Run_Time'] < 0]
extreme_large_times = combined_execution_data[combined_execution_data['Run_Time'] > combined_execution_data['Run_Time'].quantile(0.99)]

# Display the count of negative times and extreme large times, and a few examples if they exist
negative_count = negative_times.shape[0]
extreme_large_count = extreme_large_times.shape[0]

(negative_count, negative_times.head(), extreme_large_count, extreme_large_times.head())


# Removing extreme large values above the 99th percentile for visualization
cutoff = combined_execution_data['Run_Time'].quantile(0.99)
filtered_data = combined_execution_data[combined_execution_data['Run_Time'] <= cutoff]

# Now let's create a boxplot for the filtered data
plt.figure(figsize=(14, 8))
boxplot = sns.boxplot(x='SQL_File', y='Run_Time', hue='Dataset', data=filtered_data, palette="muted")

# Set the y-axis to start at 0 to avoid negative values
boxplot.set_ylim(bottom=0)

# Adding the title and labels
plt.title('Throughput Time Comparison Across Datasets (Filtered)', fontsize=20)
plt.xlabel('SQL File', fontsize=16)
plt.ylabel('Throughput Time (seconds)', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Throughput_time_cu8

# %%
# Load the remaining three files as separate datasets
execution_time_file_1 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu8/PUBLIC/execution_times.csv'
execution_time_file_2 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu8/TPCH_1G/execution_times.csv'  # Second file
execution_time_file_3 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu8/TPCH_2G/execution_times.csv'  # Third file
execution_time_file_4 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu8/TPCH_3G/execution_times.csv'  # Fourth file

data1 = pd.read_csv(execution_time_file_1)
data1['Dataset'] = 'TPCH_05G'

# Load the second file and add an identifier
data2 = pd.read_csv(execution_time_file_2)
data2['Dataset'] = 'TPCH_1G'

# Load the third file and add an identifier
data3 = pd.read_csv(execution_time_file_3)
data3['Dataset'] = 'TPCH_2G'

# Load the fourth file and add an identifier
data4 = pd.read_csv(execution_time_file_4)
data4['Dataset'] = 'TPCH_3G'

# Combine all datasets into one DataFrame
combined_execution_data = pd.concat([data1, data2, data3, data4], ignore_index=True)

# Check for any negative or extremely large run times in the combined data
negative_times = combined_execution_data[combined_execution_data['Run_Time'] < 0]
extreme_large_times = combined_execution_data[combined_execution_data['Run_Time'] > combined_execution_data['Run_Time'].quantile(0.99)]

# Display the count of negative times and extreme large times, and a few examples if they exist
negative_count = negative_times.shape[0]
extreme_large_count = extreme_large_times.shape[0]

(negative_count, negative_times.head(), extreme_large_count, extreme_large_times.head())


# Removing extreme large values above the 99th percentile for visualization
cutoff = combined_execution_data['Run_Time'].quantile(0.99)
filtered_data = combined_execution_data[combined_execution_data['Run_Time'] <= cutoff]

# Now let's create a boxplot for the filtered data
plt.figure(figsize=(14, 8))
boxplot = sns.boxplot(x='SQL_File', y='Run_Time', hue='Dataset', data=filtered_data, palette="muted")

# Set the y-axis to start at 0 to avoid negative values
boxplot.set_ylim(bottom=0)

# Adding the title and labels
plt.title('Throughput Time Comparison Across Datasets (Filtered)', fontsize=20)
plt.xlabel('SQL File', fontsize=16)
plt.ylabel('Throughput Time (seconds)', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Throughput_time_cu16

# %%
# Load the remaining three files as separate datasets
execution_time_file_1 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu16/PUBLIC/execution_times.csv'
execution_time_file_2 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu16/TPCH_1G/execution_times.csv'  # Second file
execution_time_file_3 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu16/TPCH_2G/execution_times.csv'  # Third file
execution_time_file_4 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu16/TPCH_3G/execution_times.csv'  # Fourth file

data1 = pd.read_csv(execution_time_file_1)
data1['Dataset'] = 'TPCH_05G'

# Load the second file and add an identifier
data2 = pd.read_csv(execution_time_file_2)
data2['Dataset'] = 'TPCH_1G'

# Load the third file and add an identifier
data3 = pd.read_csv(execution_time_file_3)
data3['Dataset'] = 'TPCH_2G'

# Load the fourth file and add an identifier
data4 = pd.read_csv(execution_time_file_4)
data4['Dataset'] = 'TPCH_3G'

# Combine all datasets into one DataFrame
combined_execution_data = pd.concat([data1, data2, data3, data4], ignore_index=True)

# Check for any negative or extremely large run times in the combined data
negative_times = combined_execution_data[combined_execution_data['Run_Time'] < 0]
extreme_large_times = combined_execution_data[combined_execution_data['Run_Time'] > combined_execution_data['Run_Time'].quantile(0.99)]

# Display the count of negative times and extreme large times, and a few examples if they exist
negative_count = negative_times.shape[0]
extreme_large_count = extreme_large_times.shape[0]

(negative_count, negative_times.head(), extreme_large_count, extreme_large_times.head())


# Removing extreme large values above the 99th percentile for visualization
cutoff = combined_execution_data['Run_Time'].quantile(0.99)
filtered_data = combined_execution_data[combined_execution_data['Run_Time'] <= cutoff]

# Now let's create a boxplot for the filtered data
plt.figure(figsize=(14, 8))
boxplot = sns.boxplot(x='SQL_File', y='Run_Time', hue='Dataset', data=filtered_data, palette="muted")

# Set the y-axis to start at 0 to avoid negative values
boxplot.set_ylim(bottom=0)

# Adding the title and labels
plt.title('Throughput Time Comparison Across Datasets (Filtered)', fontsize=20)
plt.xlabel('SQL File', fontsize=16)
plt.ylabel('Throughput Time (seconds)', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Snow Flake

# %% [markdown]
# ## Load Time

# %%
# List of file paths for the uploaded CSV files
file_paths = [
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/SF_LoadTime/TPCH_05_loading_times.csv',
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/SF_LoadTime/TPCH_1G_loading_times.csv',
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/SF_LoadTime/TPCH_2G_loading_times.csv',
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/SF_LoadTime/TPCH_3G_loading_times.csv'
]

# Read each CSV file and store them in a list
datasets = [pd.read_csv(file) for file in file_paths]

# Display the structure of the first dataset to understand how to combine them
datasets[0].head()

# Create a new DataFrame to hold all the combined data with an additional 'File Size' column
combined_data = pd.DataFrame()

# Loop over each dataset and append to the combined_data DataFrame
for i, dataset in enumerate(datasets):
    dataset['File Size'] = f"{i}G" if i > 0 else "0.5G"  # Assign file size based on the order
    combined_data = combined_data.append(dataset, ignore_index=True)

# Set the order of file sizes to maintain consistency in the plot
file_size_order = ["0.5G", "1G", "2G", "3G"]

pivot_data = combined_data.pivot(index='Table Name', columns='File Size', values='Loading Time')

# Define a simple color scheme
color_scheme = ['#A6CEE3', '#1F78B4', '#B2DF8A', '#33A02C']

# Plot
fig, ax = plt.subplots(figsize=(14, 10))

# We stack the bars using a cumulative sum to place them on top of each other
bottom = np.zeros(len(pivot_data))

# Loop to plot the bars
for i, col in enumerate(pivot_data.columns[::-1]):  # Reverse the order for proper stacking
    ax.bar(pivot_data.index, pivot_data[col], bottom=bottom, label=col, color=color_scheme[i])
    bottom += pivot_data[col].values

# Adding the title and labels with a more academic look
ax.set_title('Loading Times by Dataset and File Size', fontsize=20, weight='bold')
ax.set_xlabel('Dataset', fontsize=16, weight='bold')
ax.set_ylabel('Loading Time (seconds)', fontsize=16, weight='bold')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', rotation_mode='anchor', weight='bold')

# Adding a legend with a clear label
ax.legend(title='File Size', title_fontsize='13', loc='upper right', fontsize='12')

# Set the background to white with no gridlines for a clean look
ax.set_facecolor('white')
ax.grid(False)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-63-66c3126e1f37>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(dataset, ignore_index=True)
# <ipython-input-63-66c3126e1f37>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(dataset, ignore_index=True)
# <ipython-input-63-66c3126e1f37>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(dataset, ignore_index=True)
# <ipython-input-63-66c3126e1f37>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(dataset, ignore_index=True)

# %% [markdown]
# ## Execution Time

# %%
# It seems we only loaded one of the execution_times.csv files previously.
# Let's load each execution_times.csv file as a separate dataset.
# As they have the same name, we'll load them one by one to avoid confusion.

# Define the paths for the three execution_times files (assuming they are different)
execution_times_paths = [
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/PUBLIC/execution_times.csv',  # Assuming this path is for the first file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/TPCH_1/execution_times.csv',  # Assuming this path is for the second file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/TPCH_2/execution_times.csv',  # Assuming this path is for the third file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/TPCH_3/execution_times.csv'   # This is the fourth file
]

# Read the content of the CSV files
# Since the files have the same name, we'll load them one by one
execution_times_data = []
for i, path in enumerate(execution_times_paths):
    temp_data = pd.read_csv(path)
    temp_data['Dataset'] =  f"{i}G" if i > 0 else "0.5G"
    execution_times_data.append(temp_data)

# Combine all datasets into one DataFrame
combined_execution_data_all = pd.concat(execution_times_data, ignore_index=True)

# Now let's create the comparison plot for all four datasets.
plt.figure(figsize=(16, 10))
sns.boxplot(x='file_number', y='Execution Time (seconds)', hue='Dataset', data=combined_execution_data_all, palette="Set3")

# Adding the title and labels
plt.title('Comparison of SQL File Execution Times Across Four Datasets', fontsize=20)
plt.xlabel('SQL File', fontsize=16)
plt.ylabel('Execution Time (seconds)', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Re-create the boxplot without showing the outliers
plt.figure(figsize=(16, 10))
sns.boxplot(x='file_number', y='Execution Time (seconds)', hue='Dataset', data=combined_execution_data_all,
            palette="Set3", showfliers=False)  # showfliers=False will hide the outliers

# Adding the title and labels
plt.title('Comparison of SQL File Execution Times Across Four Datasets (Without Outliers)', fontsize=20)
plt.xlabel('SQL File', fontsize=16)
plt.ylabel('Execution Time (seconds)', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Throughput CU 4

# %%
# Load the remaining three files as separate datasets
execution_time_file_1 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu4/PUBLIC/execution_times_all.csv'
execution_time_file_2 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu4/TPCH_1/execution_times_all.csv'  # Second file
execution_time_file_3 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu4/TPCH_2/execution_times_all.csv'  # Third file
execution_time_file_4 = '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu4/TPCH_3/execution_times_all.csv'  # Fourth file

data1 = pd.read_csv(execution_time_file_1)
data1['Dataset'] = 'TPCH_05G'

# Load the second file and add an identifier
data2 = pd.read_csv(execution_time_file_2)
data2['Dataset'] = 'TPCH_1G'

# Load the third file and add an identifier
data3 = pd.read_csv(execution_time_file_3)
data3['Dataset'] = 'TPCH_2G'

# Load the fourth file and add an identifier
data4 = pd.read_csv(execution_time_file_4)
data4['Dataset'] = 'TPCH_3G'

# Combine all datasets into one DataFrame
combined_execution_data = pd.concat([data1, data2, data3, data4], ignore_index=True)

# Check for any negative or extremely large run times in the combined data
negative_times = combined_execution_data[combined_execution_data['Execution_Time_sec'] < 0]
extreme_large_times = combined_execution_data[combined_execution_data['Execution_Time_sec'] > combined_execution_data['Execution_Time_sec'].quantile(0.99)]

# Display the count of negative times and extreme large times, and a few examples if they exist
negative_count = negative_times.shape[0]
extreme_large_count = extreme_large_times.shape[0]

(negative_count, negative_times.head(), extreme_large_count, extreme_large_times.head())


# Removing extreme large values above the 99th percentile for visualization
cutoff = combined_execution_data['Execution_Time_sec'].quantile(0.99)
filtered_data = combined_execution_data[combined_execution_data['Execution_Time_sec'] <= cutoff]

# Now let's create a boxplot for the filtered data
plt.figure(figsize=(14, 8))
boxplot = sns.boxplot(x='File_Number', y='Execution_Time_sec', hue='Dataset', data=filtered_data, palette="muted")

# Set the y-axis to start at 0 to avoid negative values
boxplot.set_ylim(bottom=0)

# Adding the title and labels
plt.title('Throughput Time Comparison Across Datasets (Filtered)', fontsize=20)
plt.xlabel('SQL File', fontsize=16)
plt.ylabel('Throughput Time (seconds)', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## CU 8

# %%
# Load each of the provided execution_times_all.csv files as separate datasets
file_paths = [
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/PUBLIC/execution_times_all.csv',  # Assuming this path is for the first file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/TPCH_1/execution_times_all.csv',  # Assuming this path is for the second file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/TPCH_2/execution_times_all.csv',  # Assuming this path is for the third file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/TPCH_3/execution_times_all.csv'   # Assuming this path is for the fourth file
]

# Initialize an empty list to store the dataframes
combined_execution_data = []

# Iterate over the file paths, load each file and add a dataset identifier
for i, file_path in enumerate(file_paths):
    try:
        # Load the current file
        data = pd.read_csv(file_path, error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
        # Add a dataset identifier
        data['Dataset'] = f'Dataset{i+1}'
        # Append the dataframe to the list
        combined_execution_data.append(data)
    except pd.errors.ParserError as e:
        # If a ParserError occurs, output the error message
        print(f"Error loading file {file_path}: {e}")

# Check the first few rows of each dataframe if loaded
for i, df in enumerate(combined_execution_data):
    print(f"Dataframe {i+1} head:")
    print(df.head(), '\n')

# # Check for any negative or extremely large run times in the combined data
# negative_times = combined_execution_data[combined_execution_data['Execution_Time_sec'] < 0]
# extreme_large_times = combined_execution_data[combined_execution_data['Execution_Time_sec'] > combined_execution_data['Execution_Time_sec'].quantile(0.99)]

# # Display the count of negative times and extreme large times, and a few examples if they exist
# negative_count = negative_times.shape[0]
# extreme_large_count = extreme_large_times.shape[0]

# (negative_count, negative_times.head(), extreme_large_count, extreme_large_times.head())


# # Removing extreme large values above the 99th percentile for visualization
# cutoff = combined_execution_data['Execution_Time_sec'].quantile(0.99)
# filtered_data = combined_execution_data[combined_execution_data['Execution_Time_sec'] <= cutoff]

# Now let's create a boxplot for the filtered data
plt.figure(figsize=(14, 8))
boxplot = sns.boxplot(x='File_Number', y='Execution_Time_sec', hue='Dataset', data=filtered_data, palette="muted")

# Set the y-axis to start at 0 to avoid negative values
boxplot.set_ylim(bottom=0)

# Adding the title and labels
plt.title('Throughput Time Comparison Across Datasets (Filtered)', fontsize=20)
plt.xlabel('SQL File', fontsize=16)
plt.ylabel('Throughput Time (seconds)', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-71-e33e95508118>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv(file_path, error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# <ipython-input-71-e33e95508118>:16: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv(file_path, error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# Skipping line 892: expected 4 fields, saw 5
#
# <ipython-input-71-e33e95508118>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv(file_path, error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# ...

# %% [markdown]
# ## CU 16

# %%
# Load each of the provided execution_times_all.csv files as separate datasets
file_paths = [
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/PUBLIC/execution_times_all.csv',  # Assuming this path is for the first file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/TPCH_1/execution_times_all.csv',  # Assuming this path is for the second file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/TPCH_2/execution_times_all.csv',  # Assuming this path is for the third file
    '/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/TPCH_3/execution_times_all.csv'   # Assuming this path is for the fourth file
]

# Initialize an empty list to store the dataframes
combined_execution_data = []

# Iterate over the file paths, load each file and add a dataset identifier
for i, file_path in enumerate(file_paths):
    try:
        # Load the current file
        data = pd.read_csv(file_path, error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
        # Add a dataset identifier
        data['Dataset'] = f'Dataset{i+1}'
        # Append the dataframe to the list
        combined_execution_data.append(data)
    except pd.errors.ParserError as e:
        # If a ParserError occurs, output the error message
        print(f"Error loading file {file_path}: {e}")

# Check the first few rows of each dataframe if loaded
for i, df in enumerate(combined_execution_data):
    print(f"Dataframe {i+1} head:")
    print(df.head(), '\n')

# # Check for any negative or extremely large run times in the combined data
# negative_times = combined_execution_data[combined_execution_data['Execution_Time_sec'] < 0]
# extreme_large_times = combined_execution_data[combined_execution_data['Execution_Time_sec'] > combined_execution_data['Execution_Time_sec'].quantile(0.99)]

# # Display the count of negative times and extreme large times, and a few examples if they exist
# negative_count = negative_times.shape[0]
# extreme_large_count = extreme_large_times.shape[0]

# (negative_count, negative_times.head(), extreme_large_count, extreme_large_times.head())


# # Removing extreme large values above the 99th percentile for visualization
# cutoff = combined_execution_data['Execution_Time_sec'].quantile(0.99)
# filtered_data = combined_execution_data[combined_execution_data['Execution_Time_sec'] <= cutoff]

# Now let's create a boxplot for the filtered data
plt.figure(figsize=(14, 8))
boxplot = sns.boxplot(x='File_Number', y='Execution_Time_sec', hue='Dataset', data=filtered_data, palette="muted")

# Set the y-axis to start at 0 to avoid negative values
boxplot.set_ylim(bottom=0)

# Adding the title and labels
plt.title('Throughput Time Comparison Across Datasets (Filtered)', fontsize=20)
plt.xlabel('SQL File', fontsize=16)
plt.ylabel('Throughput Time (seconds)', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-72-66b394ba98f1>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv(file_path, error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# <ipython-input-72-66b394ba98f1>:16: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv(file_path, error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# <ipython-input-72-66b394ba98f1>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv(file_path, error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# ...

# %% [markdown]
# # Comparition

# %% [markdown]
# ## Load Time

# %%
# Given load times for Google Big Query and Snow Flake for different sizes
load_times = {
    'Google Big Query': [64.816, 71.051, 77.189, 78.368],
    'Snow Flake': [19.59, 25.147, 35.521, 48.095]
}

# Sizes for the x-axis
sizes = ['0.5G', '1G', '2G', '3G']

# Prepare the data in long format for seaborn
long_format_data = {
    'Load Time': load_times['Google Big Query'] + load_times['Snow Flake'],
    'Database': ['Google Big Query']*4 + ['Snow Flake']*4,
    'Size': sizes * 2
}

df = pd.DataFrame(long_format_data)

# Now let's create a comparison plot
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.set_theme(style="whitegrid")
sns.set_context("talk")  # Larger context for presentation

# Create a bar plot
barplot = sns.barplot(x='Size', y='Load Time', hue='Database', data=df, palette='colorblind')

# Adding the title and labels
plt.title('Load Time Comparison between Google Big Query and Snow Flake', fontsize=16)
plt.xlabel('Data Size', fontsize=14)
plt.ylabel('Load Time (seconds)', fontsize=14)

# Display the legend
plt.legend(title='Database')

# Show the plot
plt.show()

# %% [markdown]
# ## Power Test

# %% [markdown]
# ### Total Time

# %%
# Load the datasets
bq_05 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/PUBLIC/execution_times.csv')
bq_1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/TPCH_1G/execution_times.csv')
bq_2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/TPCH_2G/execution_times.csv')
bq_3 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/TPCH_3G/execution_times.csv')

sf_05 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/PUBLIC/execution_times.csv')
sf_1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/TPCH_1/execution_times.csv')
sf_2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/TPCH_2/execution_times.csv')
sf_3 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/TPCH_3/execution_times.csv')

# Assuming both datasets have a similar structure with a 'Run_Time' column
# We'll create a new DataFrame for comparison, this time for a bar plot
comparison_df = pd.DataFrame({
    'Run Time': [
        bq_05['Run_Time'].mean(),  # Average run time for public dataset
        bq_1['Run_Time'].mean(),  # Average run time for public dataset
        bq_2['Run_Time'].mean(),  # Average run time for public dataset
        bq_3['Run_Time'].mean(),  # Average run time for public dataset
        sf_05['Execution Time (seconds)'].mean(),  # Average run time for execution dataset
        sf_1['Execution Time (seconds)'].mean(),  # Average run time for execution dataset
        sf_2['Execution Time (seconds)'].mean(),  # Average run time for execution dataset
        sf_3['Execution Time (seconds)'].mean()  # Average run time for execution dataset
    ],
    'Dataset': ['bq_05', 'bq_1', 'bq_2', 'bq_3', 'sf_05', 'sf_1', 'sf_2', 'sf_3']
})

# Your data here
bq_times = [bq_05['Run_Time'].mean(), bq_1['Run_Time'].mean(), bq_2['Run_Time'].mean(), bq_3['Run_Time'].mean()]
sf_times = [sf_05['Execution Time (seconds)'].mean(), sf_1['Execution Time (seconds)'].mean(), sf_2['Execution Time (seconds)'].mean(), sf_3['Execution Time (seconds)'].mean()]
sizes = ['0.5G', '1G', '2G', '3G']

# Create a DataFrame
df = pd.DataFrame({
    'Size': sizes * 2,
    'Run Time': bq_times + sf_times,
    'Platform': ['BigQuery']*4 + ['Snowflake']*4
})

# Create the comparison bar plot
plt.figure(figsize=(10, 8))
sns.set_theme(style="whitegrid")

# Create a barplot for a clear, academic comparison
barplot = sns.barplot(x='Size', y='Run Time', hue='Platform', data=df, palette='colorblind')

# Set the plot title and labels
plt.title('Power Test Comparison: BigQuery vs Snowflake', fontsize=20, fontweight='bold')
plt.xlabel('Data Size', fontsize=16, fontweight='bold')
plt.ylabel('Load Time (seconds)', fontsize=16, fontweight='bold')
plt.legend(title='Platform', fontsize=14, title_fontsize='16')

# Show the plot
plt.tight_layout()  # Adjusts the plot to ensure everything fits without overlap
plt.show()

# %% [markdown]
# ### 05 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/PUBLIC/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/PUBLIC/execution_times.csv')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"file_number": "query", "Execution Time (seconds)" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 05 GB'
df2['Dataset'] = 'Snow Flake 05 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

# Assuming 'query' is the column with query identifiers and 'time' is the column with execution times
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()

# %% [markdown]
# ### 1 GB Power Test

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/TPCH_1G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/TPCH_1/execution_times.csv')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"file_number": "query", "Execution Time (seconds)" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 1 GB'
df2['Dataset'] = 'Snow Flake 1 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

# Assuming 'query' is the column with query identifiers and 'time' is the column with execution times
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()

# %% [markdown]
# ### 2 GB Power Test

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/TPCH_2G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/TPCH_2/execution_times.csv')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"file_number": "query", "Execution Time (seconds)" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 2 GB'
df2['Dataset'] = 'Snow Flake 2 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

# Assuming 'query' is the column with query identifiers and 'time' is the column with execution times
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()

# %% [markdown]
# ### 3 GB Power Test

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Execution_time/TPCH_3G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Execution_time/TPCH_3/execution_times.csv')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"file_number": "query", "Execution Time (seconds)" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 3 GB'
df2['Dataset'] = 'Snow Flake 3 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

# Assuming 'query' is the column with query identifiers and 'time' is the column with execution times
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()

# %% [markdown]
# ## Throughput Test

# %% [markdown]
# ### CU4

# %% [markdown]
# #### 05 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu4/PUBLIC/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu4/PUBLIC/execution_times_all.csv')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 3 GB'
df2['Dataset'] = 'Snow Flake 3 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

# Assuming 'query' is the column with query identifiers and 'time' is the column with execution times
plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu4/PUBLIC/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu4/PUBLIC/execution_times_all.csv')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 05 GB'
df2['Dataset'] = 'Snow Flake 05 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()

# %% [markdown]
# #### 1 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu4/TPCH_1G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu4/TPCH_1/execution_times_all.csv')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 1 GB'
df2['Dataset'] = 'Snow Flake 1 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()

# %% [markdown]
# #### 2 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu4/TPCH_2G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu4/TPCH_2/execution_times_all.csv')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 2 GB'
df2['Dataset'] = 'Snow Flake 2 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()

# %% [markdown]
# #### 3 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu4/TPCH_3G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu4/TPCH_3/execution_times_all.csv')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 3 GB'
df2['Dataset'] = 'Snow Flake 3 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()

# %% [markdown]
# ### CU 8

# %% [markdown]
# #### 05 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu8/PUBLIC/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/PUBLIC/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 05 GB'
df2['Dataset'] = 'Snow Flake 05 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()
# Out:
# <ipython-input-84-6b53676c836f>:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/PUBLIC/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# <ipython-input-84-6b53676c836f>:4: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/PUBLIC/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# Skipping line 892: expected 4 fields, saw 5

# %% [markdown]
# #### 1 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu8/TPCH_1G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/TPCH_1/execution_times_all.csv')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 1 GB'
df2['Dataset'] = 'Snow Flake 1 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()

# %% [markdown]
# #### 2 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu8/TPCH_2G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/TPCH_2/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 2 GB'
df2['Dataset'] = 'Snow Flake 2 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()
# Out:
# <ipython-input-86-c8765a75737e>:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/TPCH_2/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# <ipython-input-86-c8765a75737e>:4: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/TPCH_2/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')

# %% [markdown]
# #### 3 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu8/TPCH_3G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/TPCH_3/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 3 GB'
df2['Dataset'] = 'Snow Flake 3 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()
# Out:
# <ipython-input-87-e464957b64c2>:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/TPCH_3/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# <ipython-input-87-e464957b64c2>:4: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu8/TPCH_3/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')

# %% [markdown]
# ### CU 16

# %% [markdown]
# #### 05 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu16/PUBLIC/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/PUBLIC/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 05 GB'
df2['Dataset'] = 'Snow Flake 05 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()
# Out:
# <ipython-input-88-974d30d4b63c>:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/PUBLIC/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# <ipython-input-88-974d30d4b63c>:4: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/PUBLIC/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')

# %% [markdown]
# #### 1 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu16/TPCH_1G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/TPCH_1/execution_times_all.csv')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 1 GB'
df2['Dataset'] = 'Snow Flake 1 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()

# %% [markdown]
# #### 2 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu16/TPCH_2G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/TPCH_2/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 2 GB'
df2['Dataset'] = 'Snow Flake 2 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()
# Out:
# <ipython-input-90-0c7441f84458>:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/TPCH_2/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# <ipython-input-90-0c7441f84458>:4: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/TPCH_2/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')

# %% [markdown]
# #### 3 GB

# %%
# Load your data
df1 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/big_query/Throughput_Bigquery/Throughput_time_cu16/TPCH_3G/execution_times.csv')

df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/TPCH_3/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')

df1.rename(columns={"SQL_File": "query", "Run_Time" : "time"}, inplace = True)
df2.rename(columns={"File_Number": "query", "Execution_Time_sec" : "time"}, inplace = True)

# Add an identifier column
df1['Dataset'] = 'Google Big Query 3 GB'
df2['Dataset'] = 'Snow Flake 3 GB'

# Concatenate the dataframes
df = pd.concat([df1, df2])

plt.figure(figsize=(16, 12))
sns.barplot(data=df, x='query', y='time', hue='Dataset')

# Set the y-axis to log scale to better visualize disparities in execution time
plt.yscale('log')

plt.title('Execution Time Comparison by Query')
plt.xlabel('Query Identifier')
plt.ylabel('Execution Time (seconds)')
plt.legend(title='Dataset')

plt.show()
# Out:
# <ipython-input-91-ade34002e59b>:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/TPCH_3/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
# <ipython-input-91-ade34002e59b>:4: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2 = pd.read_csv('/content/drive/MyDrive/ADB-Dataware-housing-with-Google-bigquery-and-snowflake-main/snow_flake/Throughput_snowflake/Throughput_time_cu16/TPCH_3/execution_times_all.csv', error_bad_lines=False, warn_bad_lines=True, encoding='latin1')
